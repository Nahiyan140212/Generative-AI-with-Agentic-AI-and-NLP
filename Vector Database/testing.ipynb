# %%
# Using requests library for embeddings
import requests
import numpy as np

def generate_embeddings(text):
    url = "https://api.euron.one/api/v1/euri/alpha/embeddings"
    headers = {
        "Content-Type": "application/json",
        "Authorization": "Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiI4ZDkyYTA4OC1jMzlkLTQ0MTUtOTlhYy0xNWVhNWVhZDI4MTAiLCJlbWFpbCI6Im5haGl5YW4uY3VldEBnbWFpbC5jb20iLCJpYXQiOjE3NDM3Mjk2NTEsImV4cCI6MTc3NTI2NTY1MX0.uOW_s9wmQpCZzJU4qK-O6g8k3_Gh-nW7AKoqnIcw_MI"
    }
    payload = {
        "input": text,
        "model": "text-embedding-3-small"
    }

    response = requests.post(url, headers=headers, json=payload)
    data = response.json()
    
    # Convert to numpy array for vector operations
    embedding = np.array(data['data'][0]['embedding'])
    
    print(f"Generated embedding with shape: {embedding.shape}")
    print(f"First 5 values: {embedding[:5]}")
    
    # Example: Calculate vector norm
    norm = np.linalg.norm(embedding)
    print(f"Vector norm: {norm}")
    
    return embedding

# %%
text1 = "The patient is diagnosed with Opioid Use Disorder today"
text2 = "He is planning to start medication"
text3 = "Dr. Nalin prescribed Buprenorphine to this patient"
texts = ['text1', 'text2', 'text3']

# %%
embedded = []
for text in texts:
    embedded.append(generate_embeddings(text))
# Out:
# Generated embedding with shape: (1536,)
# First 5 values: [-0.00824118 -0.00450385  0.04468218 -0.00340171 -0.00132174]
# Vector norm: 0.999999974575416
# Generated embedding with shape: (1536,)
# First 5 values: [-0.02575638 -0.01182561 -0.01563724 -0.03789299 -0.02312493]
# Vector norm: 1.0000000122253818
# Generated embedding with shape: (1536,)
# First 5 values: [-0.01576419  0.00231876  0.0248354  -0.02714566 -0.00175712]
# Vector norm: 1.0000000041248174

# %%
print(embedded)
# Out:
# [array([-0.00824118, -0.00450385,  0.04468218, ..., -0.02945112,
#        -0.00025909,  0.00047778]), array([-0.02575638, -0.01182561, -0.01563724, ..., -0.01054975,
#         0.00594071,  0.0116741 ]), array([-0.01576419,  0.00231876,  0.0248354 , ...,  0.00296853,
#         0.01426931,  0.02386712])]

# %%
cosine_similarty1 = np.dot(embedded[0],embedded[1])/(np.linalg.norm(embedded[0])*np.linalg.norm(embedded[1]))

# %%
1 -cosine_similarty1
# Out:
# 0.3029735293133673

# %%
cosine_similarty2 = np.dot(embedded[0],embedded[2])/(np.linalg.norm(embedded[0])*np.linalg.norm(embedded[2]))

# %%
1 -cosine_similarty2
# Out:
# 0.3129899369845811

# %%
1-np.dot(embedded[1],embedded[2])/(np.linalg.norm(embedded[1])*np.linalg.norm(embedded[2]))
# Out:
# 0.3012520570092633

# %% [markdown]
# pip install chroma
# chroma run --path ./chromadb_data
